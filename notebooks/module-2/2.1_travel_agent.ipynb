# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    # "gpt-5-nano",
    model=model,
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='bb42c895-cba6-461f-b70a-25203e9b601e'),
# ...

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct, non-stop options from San Francisco to Tokyo on 31 March 2027. Prices are in EUR and shown for economy where applicable.
#
# | Route | Outbound (local) | Cabin | Duration | Price | Booking |
# |---|---|---|---|---|---|
# | SFO → NRT | 31 Mar 12:20 → 01 Apr 15:25 (11h 05m) | Economy | 39900s | 403 EUR | [Book NH7](https://kiwi.com/u/zdnjzc) |
# | SFO → HND | 31 Mar 01:45 → 01 Apr 05:00 (11h 15m) | Economy | 40500s | 1068 EUR | [Book NH107](https://kiwi.com/u/6p6z4h) |
# | SFO → NRT | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 40800s | 1180 EUR | [Book UA837](https://kiwi.com/u/u8ufzz) |
# | SFO → NRT | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 40800s | 1187 EUR | [Book NH7013](https://kiwi.com/u/hpcfv8) |
# | SFO → NRT | 31 Mar 11:40 → 01 Apr 15:25 (11h 20m) | Economy | 40800s | 1195 EUR | [Book UA7949](https://kiwi.com/u/zf2xv9) |
# ...

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from Yerevan to Paris on October 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='bb42c895-cba6-461f-b70a-25203e9b601e'),
# ...

# %%
print(response["messages"][-1].content)
# Out:
# Direct flights from Yerevan (EVN) to Paris (CDG) on October 31, 2026
#
# | Route | Outbound (local) | Cabin | Duration | Price | Booking |
# |---|---|---|---|---|---|
# | EVN → CDG | 31 Oct 2026, 09:05 → 11:35 (5h 30m) | Economy | 5h 30m | 250 EUR | [Book FlyOne Armenia 3F3927](https://kiwi.com/u/gxy777) |
# | EVN → CDG | 31 Oct 2026, 15:50 → 18:10 (5h 20m) | Economy | 5h 20m | 1260 EUR | [Book Air France AF1061](https://kiwi.com/u/mf8ymh8) |
#
# Notes
# - All times are local to the departure/arrival airports.
# - The FlyOne Armenia option is the cheapest direct flight; Air France offers the traditional full-service experience.
# - Airports: EVN (Zvartnots International) to Paris CDG (Charles de Gaulle).
#
# Recommendation: If price is your priority, choose the FlyOne Armenia option (250 EUR). If you prefer the higher service level and airline reputation, go with Air France (AF1061, 1260 EUR).
#
# ...

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from Yerevan to Tehran on October 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='bb42c895-cba6-461f-b70a-25203e9b601e'),
# ...

# %%
print(response["messages"][-1].content)
# Out:
# No direct flights from Yerevan to Tehran on October 31, 2026. Here are the cheapest one-stop options for that date (via Istanbul or Istanbul Sabiha Gökçen to Tehran Imam Khomeini, IKA):
#
# Cheapest options
# - Route: EVN → SAW → IKA (Pegasus + AJet)
#   - Outbound: 31 Oct 2026, 04:15 → 01 Nov 2026, 01:35
#   - Total duration: about 21h 50m
#   - Cabin: Economy
#   - Price: 300 EUR
#   - Booking: https://kiwi.com/u/7rdpf24
#
# - Route: EVN → IST → IKA (Turkish Airlines TK359 + TK874)
#   - Outbound: 31 Oct 2026, 04:15 → 01 Nov 2026, 02:45
#   - Total duration: about 25h 30m
#   - Cabin: Economy
#   - Price: 331 EUR
#   - Booking: https://kiwi.com/u/smgbb5
#
# - Route: EVN → IST → IKA (Turkish Airlines TK359 + TK872)
#   - Outbound: 31 Oct 2026, 04:15 → 01 Nov 2026, 02:45
#   - Total duration: about 25h 30m
#   - Cabin: Economy
#   - Price: 333 EUR
#   - Booking: https://kiwi.com/u/smgbb5
#
# Notes
# ...
