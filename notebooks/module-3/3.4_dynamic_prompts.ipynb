# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-4.1-nano")

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dataclass
class LanguageContext:
    user_language: str = "English"

@dynamic_prompt
def user_language_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on user role."""
    user_language = request.runtime.context.user_language
    base_prompt = "You are a helpful assistant."

    if user_language != "English":
        return f"{base_prompt} only respond in {user_language}."
    elif user_language == "English":
        return base_prompt

# %%
from langchain.agents import create_agent

agent = create_agent(
    # model="gpt-5-nano",
    model=model,
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Irish")
)

print(response["messages"][-1].content)
# Out:
# Dia dhuit! Tá mé go maith, go raibh maith agat. Conas atá tú?

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Spanish")
)

print(response["messages"][-1].content)
# Out:
# Hola, ¿cómo estás?

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Farsi")
)

print(response["messages"][-1].content)
# Out:
# سلام، حال شما چطور است؟

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Persian")
)

print(response["messages"][-1].content)
# Out:
# سلام، حال شما چطور است؟

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="French")
)

print(response["messages"][-1].content)
# Out:
# Bonjour, je vais bien, merci. Et vous, comment ça va ?

# %%
print(response["messages"][-1].response_metadata["model_name"])
# Out:
# openai/gpt-4.1-nano

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Armenian")
)

print(response["messages"][-1].content)
# Out:
# Բարև, ես լավ եմ: Քեզ համար ինչպե՞ս կարող եմ օգնել:

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Russian")
)

print(response["messages"][-1].content)
# Out:
# Здравствуйте! Я хорошо, спасибо. Как я могу вам помочь?

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Russioon")
)

print(response["messages"][-1].content)
# Out:
# Здравствуйте! Я хорошо, спасибо. А как у вас дела?
