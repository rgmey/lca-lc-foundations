# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.
agent = create_agent(model=model)
# agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon has no government, population, or capital city. (In fiction, authors sometimes imagine a place like “Lunapolis” or “Selene City,” but there’s no official capital.)

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Selene Prime.
#
# - Location: Carved into the basin of Tycho Crater on the near side, where lunar daylight can reach the heart of the city through translucent domes and solar-sail roofs.
# - Government: Lunar Commonwealth — a technocratic republic with a bicameral Lunar Assembly and an elected Prime Auditor who presides over the executive council.
# - Population: Tens of millions (the heartbeat of a growing lunar society).
# - Architecture: A blend of basalt and regolith with transparent skylights, lava-tube tunnels, and large, curved arcologies. Daylight is collected by solar sails on the rim and funneled through crystaline domes for a soft, Earthlike glow.
# - Landmarks:
#   - Lumen Spire: A colossal, multifaceted tower that funnels sunlight into the city’s core and doubles as the main data hub.
#   - Earth Gate: A monumental arch facing Earth, used for ceremonies and diplomatic broadcasts.
#   - Archive of Echoes: A subterranean data temple carved into the crater’s basalt, housing a vast legacy of lunar science and art.
#   - Noctis Greenhouses: A district of hydroponics and arboreal gardens maintained in near-zero gravity.
# - Economy: He-3 and water-ice mining, advanced biotech, and a thriving solar-energy export network. The Moon anchors Earth’s spaceports with refueling, manufacturing, and research.
# - Daily life: Low gravity makes long-legged walkways and hopping transit common. Everyone wears adaptive suits indoors, and public spaces feature gentle gravitation to mimic Earthlike movement. Art and music bloom in microgravity, with holographic performances and sculpture born from regolith dust.
# - Culture: A pragmatic, utopian ethos—science, exploration, and a shared responsibility for Earth’s shielded energy future.
#
# If you’d like a different vibe, I can spin up another capital—say, a far-side capital inside a giant cavern, or a floating city in a glow-lit regolith sea.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunapolis — the capital of the Moon. A crescent-lit city of domes and spires in Mare Tranquillitatis, powered by solar arrays and ice-harvested energy.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Mare Tranquillitatis, on a terraced crater rim near the Apollo 11 site
# Vibe: Luminous, austere, cosmopolitan
# Economy: Helium-3 mining; lunar manufacturing and robotics; spaceport services and lunar tourism

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location='A shielded crater city in Mare Imbrium, linked to orbital hubs and surface rail networks by the Crescent Ring.', vibe='crystal-lit, tranquil, ultramodern with glass-domed districts and living regolith gardens.', economy='Helium-3 mining, water-ice processing, microgravity manufacturing, lunar biotech, and science tourism.')

# %%
response["structured_response"].name
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris Prime is a city located at A shielded crater city in Mare Imbrium, linked to orbital hubs and surface rail networks by the Crescent Ring.
