# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

# model = init_chat_model(model="gpt-5-nano")

from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re thinking of fiction or future plans, some stories imagine lunar cities or capitals, but nothing real exists today. Want examples from science fiction or a quick note on how a future lunar government might work?', additional_kwargs={'reasoning_content': '**Answering the capital of the Moon**\n\nI need to respond to the question: "What\'s the capital of the Moon?" It\'s a trick question because the Moon isn\'t a country and, therefore, has no capital. I can say something like, "There is no capital; the Moon isn\'t a sovereign entity." \n\nI could also share fun facts about proposed lunar bases like a "Moon capital" concept, which some call "Luna City." It might also be good to mention that in many fictional works, the Moon has no government.**Responding about the Moon\'s capital**\n\nIt looks like I need to address a factual question about the Moon\'s capital. I\'ll say something like, "There is no capital of the Moon because it\'s not a country or governed entity." \n\nI could also mention fictional places like "Luna City" or “Artemis" from sci-fi stories, but nothing is official. It might be helpful to note that while there are lunar settlements, any would be temporary. If they were asking about map locations, crater names could work. Overall, I\'ll keep it concise with my final answer emphasizing that the Moon has no capital.**Discussing the Moon\'s governance**\n\nI can certainly talk about proposed lunar settlements or how humans might govern the Moon in the future. \n\nFirst, a clear answer is, "There is no capital; the Moon is not a political entity." \n\nIf the user meant a fictional setting, I can mention that some sci-fi stories may reference capitals like "Calypso" or "Luna City," but I think it’s safer to avoid naming specific fictional capitals unless I\'m certain. It’s okay to say that "in some sci-fi universes, there could be Moon cities," but I should be cautious with details to avoid inaccuracies.**Clarifying the Moon\'s capital**\n\nI can confidently say there is no capital of the Moon because it’s not a country or governed entity; it\'s a natural satellite of Earth. \n\nIf the user is curious about fictional scenarios, I could mention that some sci-fi stories include lunar capitals, but again, none exist in reality. I might also offer a brief fun fact about the Moon having no atmosphere and long days and nights, but that might not be necessary right now.\n\nI\'ll conclude by asking if they want to know more about potential governance or popular fictional examples!', 'reasoning_details': [{'summary': '**Answering the capital of the Moon**\n\nI need to respond to the question: "What\'s the capital of the Moon?" It\'s a trick question because the Moon isn\'t a country and, therefore, has no capital. I can say something like, "There is no capital; the Moon isn\'t a sovereign entity." \n\nI could also share fun facts about proposed lunar bases like a "Moon capital" concept, which some call "Luna City." It might also be good to mention that in many fictional works, the Moon has no government.**Responding about the Moon\'s capital**\n\nIt looks like I need to address a factual question about the Moon\'s capital. I\'ll say something like, "There is no capital of the Moon because it\'s not a country or governed entity." \n\nI could also mention fictional places like "Luna City" or “Artemis" from sci-fi stories, but nothing is official. It might be helpful to note that while there are lunar settlements, any would be temporary. If they were asking about map locations, crater names could work. Overall, I\'ll keep it concise with my final answer emphasizing that the Moon has no capital.**Discussing the Moon\'s governance**\n\nI can certainly talk about proposed lunar settlements or how humans might govern the Moon in the future. \n\nFirst, a clear answer is, "There is no capital; the Moon is not a political entity."  ...

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re thinking of fiction or future plans, some stories imagine lunar cities or capitals, but nothing real exists today. Want examples from science fiction or a quick note on how a future lunar government might work?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'cost': 0.00032865,
#  'cost_details': {'upstream_inference_completions_cost': 0.000328,
#                   'upstream_inference_cost': 0.00032865,
#                   'upstream_inference_prompt_cost': 6.5e-07},
#  'created': 1787500525,
#  'finish_reason': 'stop',
#  'id': 'gen-1787500525-RAOrAgaN2i2GqkUm7UXP',
#  'logprobs': None,
#  'model_name': 'openai/gpt-5-nano',
#  'model_provider': 'openrouter',
#  'object': 'chat.completion'}

# %% [markdown]
# ## Customising your Model

# %%
model = ChatOpenRouter(
model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. (If you’re imagining fiction, you could invent a capital name like “Lunopolis.”)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-6")
#       2
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1947, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1945 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1946 try:
# -> 1947     data = self._create(payload)
#    1948 except anthropic.BadRequestError as e:
#    1949     _handle_anthropic_bad_request(e)
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1577, in ChatAnthropic._create(self, payload)
#    1575 if "betas" in payload:
#    1576     return self._client.beta.messages.create(**payload)
# -> 1577 return self._client.messages.create(**payload)
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1050, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1043     warnings.warn(
#    1044         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1045         UserWarning,
#    1046         stacklevel=3,
#    1047     )
#    1049 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050 return self._post(
#    1051     "/v1/messages",
#    1052     body=maybe_transform(
#    1053         {
#    1054             "max_tokens": max_tokens,
#    1055             "messages": messages,
#    1056             "model": model,
#    1057             "cache_control": cache_control,
#    1058             "container": container,
#    1059             "inference_geo": inference_geo,
#    1060             "metadata": metadata,
#    1061             "output_config": output_config,
#    1062             "service_tier": service_tier,
#    1063             "stop_sequences": stop_sequences,
#    1064             "stream": stream,
#    1065             "system": system,
#    1066             "temperature": temperature,
#    1067             "thinking": thinking,
#    1068             "tool_choice": tool_choice,
#    1069             "tools": tools,
#    1070             "top_k": top_k,
#    1071             "top_p": top_p,
#    1072         },
#    1073         message_create_params.MessageCreateParamsStreaming
#    1074         if stream
#    1075         else message_create_params.MessageCreateParamsNonStreaming,
#    1076     ),
#    1077     options=make_request_options(
#    1078         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1079     ),
#    1080     cast_to=Message,
#    1081     stream=stream or False,
#    1082     stream_cls=Stream[RawMessageStreamEvent],
#    1083 )
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Documents\Cursor\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}, 'request_id': 'req_011CeKxSncDPZXH4CPK2ZvAq'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-6")

# %%
agent = create_agent("gpt-5-nano")

# %%
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.
agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='21ea4565-3c89-4f5a-83cd-082268a69350'),
#               AIMessage(content='There isn’t one. The Moon is not a country or political entity, so it has no capital. There are no permanent settlements yet (only spacecraft, landers, and temporary missions). If you’re writing fiction, you could invent a capital name—e.g., Lunaris, Selene, or Artemis City.', additional_kwargs={'reasoning_content': '**Explaining the Moon\'s status**\n\nThe user asked, "What\'s the capital of the Moon?" This seems like a silly question since the Moon doesn\'t have a government or capital. I\'ll reply concisely that there is no capital because the Moon is a natural satellite, not a political entity. If the user is looking for something imaginative, I can mention fictional lunar cities from science fiction. It\'s essential to keep my response brief and accurate while mentioning that the Moon is uninhabited, though there are plans for human outposts like the Artemis program.**Clarifying the Moon\'s status**\n\nThe Moon doesn\'t have a government, so there is no capital or largest city. Currently, it has no permanent settlements, just temporary landers. Some people propose names like "Luna City," but nothing is official. If the user meant this as a joke, I could say "Lunapolis," which is fictional. For a straightforward answer: there’s no capital because the Moon isn\'t a country or political entity, and any governance would be based on international treaties rather than national laws.**Crafting the Moon\'s response**\n\nI need to keep my answer brief since the user asked for one sentence. The direct response is that there is no capital of the Moon because it isn\'t a country or political entity. Currently, there are no permanent settlements, just spacecraft and landers. In the future, there could be colonies that choose a capital, but none exist now. If they\'re looking for a fictional name, they could use something like "Selena," "Lunaria," or "Artemis." That should cover it!', 'reasoning_details': [{'summary': '**Explaining the Moon\'s status**\n\nThe user asked, "What\'s the capital of the Moon?" This seems like a silly question since the Moon doesn\'t have a government or capital. I\'ll reply concisely that there is no capital because the Moon is a natural satellite, not a political entity. If the user is looking for something imaginative, I can mention fictional lunar cities from science fiction. It\'s essential to keep my response brief and accurate while mentioning that the Moon is uninhabited, though there are plans for human outposts like the Artemis program.**Clarifying the Moon\'s status**\n\nThe Moon doesn\'t have a government, so there is no capital or largest city. Currently, it has no permanent settlements, just temporary landers. Some people propose names like "Luna City," but nothing is official. If the user meant this as a joke, I could say "Lunapolis," which is fictional. For a straightforward answer: there’s no capital because the Moon isn\'t a country or political entity, and any governance would be based on international treaties rather than national laws.**Crafting the Moon\'s response**\n\nI need to keep my answer brief since the user asked for one sentence. The direct response is that there is no capital of the Moon because it isn\'t a country or political entity. Currently, there are no permanent settlements, just spacecraft and landers. In the future, there could be colonies that choose a capital, but none exist now. If they\'re looking for a fictional name, they could use something like "Selena," "Lunaria," or "Artemis." That should cover it!', 'type': 'reasoning.summary', 'format': 'openai-responses-v1', 'index': 0}, {'data': 'gAAAAABqixueBrBgtRoEIYAG_FIOwocbuXymPpZIVRlKX28aBM0z3TXfWw44ziCIcCRnKR0lQZhl7ghLNER0YdJWG-9-foV7UXetPjFzb2fKq5UQqthM7_Ykx7I7lilWb6s-U0qEnTDu12eMAOUc-CAbXxSxuivTJDod0YHOMa6Z379iKFbuV-mlNAfYz2mXFpyyKW5k2wVTvVFIxIZl61BCAXdyHSgHvSXUKhFb5U6FUOYpOWGj1pHolNs2IbNU1viOqEGRVshh9LsQE-5BXTmStXgX-gi6qbfaspXwVLY70V9t3mmM0gDm7dcgDkCOWwtGVZ1GBfEiH5l9G4KsfWkupseT ...

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon is not a country or political entity, so it has no capital. There are no permanent settlements yet (only spacecraft, landers, and temporary missions). If you’re writing fiction, you could invent a capital name—e.g., Lunaris, Selene, or Artemis City.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='e03e873e-1795-4435-b172-5365e404d5a4'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='a0d90999-85b8-4ab7-a5e5-f27410bf4c9d', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='be3ab25f-c2c9-47b2-a282-cd742aeaa018'),
#               AIMessage(content='There isn’t a real capital on the Moon—no country or city has been established there yet. Luna City is a fun idea from fiction or worldbuilding. If you’d like, here’s a rich fictional concept you can use or adapt.\n\nFictional profile: Luna City\n- Location: A sheltered site near the lunar south pole, chosen for near-continuous sunlight for power and nearby water ice in permanently shadowed craters.\n- Government: A city-state under a Lunar Charter, with a Council of Representatives and a Earth liaison office. Decisions balance self-governance with support from international space agencies and private companies.\n- Population: Tens of thousands of engineers, scientists, technicians, healthcare workers, educators, and families in a dense network of habitats and tunnels.\n- Architecture and habitats: A mix of 3D-printed modular domes, inflatable habitats, and regolith-shielded tunnels. Rad protection, dust control, and radiation shielding are built into every structure. \n- Power and life support: Solar arrays on crater rims with large energy storage banks; compact nuclear microreactors as backup. Closed-loop life support recycles air, water, and waste; vertical farms supply fresh produce.\n- Transportation: Robotic tugs and wheel-based rovers for surface travel, with a lunar elevator or rail system linking surface hubs to a central hub. Personal mobility is mostly within a local district; inter-district transit is via pressurized transit shuttles.\n- Economy: Resource extraction (water ice, oxygen, mineral feedstocks), in-situ manufacturing (3D-printed parts, tools, research equipment), life-support tech, and lunar tourism for education and research missions.\n- Daily life and culture: A blend of Earth cultures adapted to low gravity and long work shifts. Shared meals feature hydroponic greens and lab-grown proteins. Community events celebrate Earth holidays and lunar milestones; education emphasizes STEM, geology, and planetary protection.\n- Challenges and conflicts: Radiation exposure, micrometeorite risk, dust management, supply logistics, and governance issues like fair resource sharing and maintaining civil liberties in a closed environment.\n- Notable landmarks: \n  - Helios Dome: the main research and energy hub with daylight-facing solar farms.\n  - Ice Vault: a reinforced facility for extracting and storing water ice.\n  - Crater Market: a community hub for trade, culture, and education.\n  - Lumen Square: central plaza for gatherings, ceremonies, and demonstrations of new tech.\n- Sample lore hook: A decades-long treaty, the Luna Compact, governs resource use and research access, but a recent dispute over mineral rights threatens to spark a political crisis just as a major scientific breakthrough is announced.\n\nIf you’d prefer, I can tailor Luna City to a specific genre (hard sci-fi, space opera, cozy sci-fi, thriller) or flesh out a full short story outline set in Luna City. I can also give a realistic overview of what a future Moon base might look like under current space-agency plans and technology trends, without the fictional aspects. Which would you like?', additional_kwargs={'reasoning_content': '**Correcting misinformation about Luna City**\n\nThe user is asking about Luna City after I mentioned it as the Moon\'s capital, but that\'s fictional. I need to gently correct this by stating there is no capital on the Moon since it\'s not a country. Any mention of "Luna City" would be purely fictional. I should outline speculative details on what a fictional Luna City could be like, including governance and daily life. Plus, I should mention the actual Moon has no permanent settlements as of 2026.**Providing accurate Moon information**\n\nThe Moon has features like maria and craters, but there are no actual cities—only fictional or planned future colonies. The Artemis program aims to establish a sustainable presence by the late 2020s or 2030s, including a lunar gateway and base cam ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is the capital of the Moon in this fictional setting—a shining administrative, scientific, and cultural hub carved into the Moon’s geology and built to endure the harsh, airless environment. It blends ultramodern governance with pragmatic frontier engineering, creating a city that feels both timeless and forward-looking.
#
# Overview
# - Role: Political and cultural heart of the Moon, seat of the Lunar Commonwealth (or Lunar Federation, depending on your preferred polity). It houses the central government, major research institutions, finance, media, and a large, diverse population.
# - Vibe: A technocratic, safety-first metropolis with towering spires, expansive domes, and a labyrinth of shielded tunnels. It’s a place where public life feels ceremonial yet relentlessly practical.
#
# Geography and Environment
# - Location: An equatorial belt that sits along a complex network of lava tubes and shielded caverns. The core districts sit inside lava tubes and hollowed craters, while surface-facing rings host solar farms and weather-resistant housing.
# - Climate and living conditions: The Moon has no breathable atmosphere and no weather, but Luna City is climate-controlled. Residents move through air-filled interiors, protected from radiation and micrometeoroids by multiple layers of regolith shielding, inflatable habitats, and hardened glass.
# - Day/night cycle: A 29.5-day lunar day means long “days” of sunlight and “nights” of darkness. The city uses synchronized lighting, artificial day-night cycles, and energy-efficient thermal management to mimic Earth-like comfort while conserving power.
# - Radiation and safety: Radiation storms and solar flares are mitigated with thick shielding, magnetic megalines, and subterranean or vacuum-tolerant infrastructure.
#
# Government and Politics
# - Polity: The Lunar Commonwealth (or Lunar Federation) governs the Moon as an extraterritorial body with a dedicated capital. Luna City houses the executive, legislative, and judiciary hubs.
# - Key institutions:
#   - The Council Spire: The seat of the planetary council, where representatives debate lunar policy, Earth relations, resource rights, and science funding.
#   - The Orbital Liaison Bureau: Manages Earth-Moon relations, trade agreements, and interplanetary governance.
#   - The Lunar Bank and Credit Authority: A financial hub that balances lunar resource rights, off-world investments, and citizen accounts.
#   - The Ministry of Ground and Sky: Oversees surface infrastructure, radiation safety, environmental controls, and public works.
# - Society of governance: A blend of technocratic committees, public assemblies, and expert panels. Security services are professional and civilian-minded, focusing on civil order, disaster readiness, and cyber-resilience.
#
# Society and Culture
# - Inhabitants: A diverse mix of Earth-born settlers, long-term lunar residents, scientists, engineers, administrators, and people from other colonies who consider Luna City a political or cultural center.
# - Daily life: Work-life revolves around orbital schedules, research cycles, and transit windows. There’s a culture of public service but also of personal innovation—people often participate in citizen-science projects, art collaborations, and open-architecture projects that adapt urban spaces.
# - Language and customs: Common language is a blend of Earth-derived languages (often English as a lingua franca) with a growing lunar sign language for accessibility. Ceremonies honor both Earth origins and lunar achievements; festivals celebrate science, exploration, and harvests from lunar agriculture.
# - Arts and recreation: Luna City hosts a renaissance of culture: holographic theaters, lunar opera, digital art communes, and “silence concerts” in domed caverns with optimized acoustics. Public spaces double as laboratories for social experiments, urban farming, and citizen-led planning.
# - Religion and philosophy: Largely secular and human-centric, with philosophical traditions focused on exploration, responsibility to future generations, and a reverence for Earth and Moon heritage. Some traditions borrow from ancient Earth mythologies about Selene, the Moon goddess, shaping a secular mythos around exploration.
#
# Economy and Infrastructure
# - Economic backbone: A balanced economy of lunar resource exploitation (water ice, mineral regolith, helium-3), high-tech services, research funding, and lunar- Earth trade. Luna City is the administrative hub that coordinates mining, refining, and distribution.
# - Key industries:
#   - Research and development: Space medicine, gravity biology, materials science, closed-loop life support, 3D printing with lunar regolith, autonomous systems.
#   - Resource processing: Extraction and refinement of oxygen, water from polar ice deposits elsewhere, and minerals for construction and manufacturing.
#   - Finance and governance services: Public finance, policy think tanks, legal services for space commerce, and cyber-legal frameworks.
#   - Culture and tourism (to Earth and other colonies): Museums, architecture tours inside lava tubes, and virtual-reality experiences of lunar exploration.
# - Energy: Solar arrays and nuclear microreactors provide power. The city uses energy storage, smart grids, and energy recycling to balance supply during long nights.
# - Housing and districts: A mix of hardened domes, gravity-assisted towers, and underground wards. Dwelling units emphasize modularity, rapid reconfiguration, and access to communal farms and labs.
#
# Technology and Science
# - Construction: 3D-printed basalt concrete, regolith-based shielding, and inflatable habitats combined with rigid shells for flexibility and safety.
# - Transportation:
#   - Local transit includes maglev tramways through tube networks and gravity-stabilized elevators between different city layers.
#   - Surface transit uses wheeled rovers and crewed shuttles to and from surface launch pads.
#   - Earth-Moon links: Orbital depots, dedicated shuttles, and lunar elevators from surface to low lunar orbit (LLO).
# - Information and AI: A distributed AI backbone manages city services, with strong emphasis on transparency, privacy, and citizen oversight. Human operators and AI collaborate in governance, safety, and logistics.
# - Healthcare and life science: Lunar medicine thrives on low-gravity biology, radiation research, and closed-loop medical systems. Telepresence and robotics support patients in high-risk environments.
# - Education and research: The Luna City University System offers programs in lunar geology, astroengineering, AI ethics, space law, and life support engineering. Open-access data and citizen science are prized.
#
# History and Timeline (outline)
# - Early outposts: A series of robotic and human stations establish lunar governance and infrastructure around a century prior to Luna City’s current era.
# - Founding era: Luna City grows from a shielded hub within a lava-tube complex, becoming the de facto capital as Earth-Lunar politics formalize.
# - Independence era: The Lunar Commonwealth announces autonomy or enhanced self-government, with Luna City as the political center.
# - Modern era: A balance of Earth lunar trade, science missions, and citizen-led development cements Luna City as a stable, culturally vibrant capital.
#
# Districts and Landmarks (examples)
# - The Council Spire: A towering glass-fronted pinnacle where laws are drafted and debated; it’s both symbol and actual seat of power.
# - The Lumen Dome District: The residential-heart of the city, featuring interconnected domes with parks, gardens, and schools.
# - The Aurora Ring: A ring-of-habitats around a central core, housing research labs, hospitals, and cultural centers.
# - The Glass Market: An open indoor-outdoor bazaar of lunar crafts, food labs, and lunar-regolith glass artistry.
# - The Observatory Spine: A long corridor of telescopes and sensors for astronomical observation and Earth-Mun communications.
# - The Arcadia Greenhouses: Large, climate-controlled farming complexes supplying fresh produce to the city and exporting surplus.
# - The Archives of Selene: A monumental library and data commons housing lunar history, scientific data, and cultural records.
# - The Vault Parks: Public spaces that store and display ancient Earth artifacts alongside lunar relics.
#
# Security, Defense, and Diplomacy
# - Security posture: A professional civil service with a focus on cybernetics, space-law enforcement, and disaster response. Public safety emphasizes community resilience and transparent governance.
# - Defense posture: Defensive capabilities exist to deter external threats and protect critical infrastructure, with a focus on non-provocative deterrence and rapid mobilization in emergencies.
# - Earth relations: Luna City maintains diplomatic centers and trade routes with Earth, other lunar bases, and space stations; diplomacy stresses mutual benefit and mutual restraint.
#
# Challenges and Threats
# - Environmental risks: Long lunar nights test life-support systems; radiation storms require continuous upgrades to shielding and backup power.
# - Resource pressure: Competition for water, oxygen, and rare minerals persists in a frontier economy; supply disruption could ripple through governance.
# - Political tensions: Earth-Moon relations can be fraught; Luna City must balance autonomy with cooperation, ensuring internal stability while engaging diplomatically.
# - Social issues: Wealth disparities, housing pressure, and the changing role of science in governance can create social tension; robust civic engagement is essential.
#
# Famous People and Organizations
# - The Prime Administrator: The elected leader who heads the city’s executive branch.
# - The Lunar Councilors: Elected or appointed representatives who guide policy at the Council Spire.
# - The Institute for Lunar Studies: Prestigious research body advancing lunar science and technology.
# - The Moon Rangers: A public-safety and search-rescue unit responsible for disaster response and surface operations.
# - The Archival Guild: Custodians of lunar history, cultural artifacts, and open data initiatives.
#
# Life in Luna City: a Snapshot
# - A typical day might begin with a sunrise glow across the domes, followed by a community breakfast in the Greenhouses, a commute through a tunnel network on a maglev tram, a seminar at the University, and a late afternoon at a public park overlooking a city plaza inside a shielded crater.
# - People pursue dual careers: a scientist might also design urban systems, while a civil servant might code open-data dashboards for public use.
# - Public events often blend ceremony with science: a “Light Festival” that uses solar optics to map the city’s energy systems, or a “Harbor of Stars” night market featuring lunar-grown foods and holo-art.
#
# How to Use Luna City in Your World
# - As a setting for political intrigue: A new trade agreement with Earth could unravel inside the Council Spire; an unexpected water-discovery might trigger a resource-backed policy shift.
# - As a backdrop for science fiction stories: A research team battles a radiation anomaly or tests a new gravity-modulation technology.
# - As a cultural hub: A festival or protest space reveals the city’s social dynamics and citizen voices.
# - As a location for character-focused tales: A public administrator balancing ethics and efficiency, a scientist navigating funding, or a rover pilot dealing with a crisis.
#
# Plot hooks and ideas
# - A water-ice discovery at the polar edge triggers a lunar-wide political crisis over ownership and transit rights, forcing Luna City to broker a daring, multi-party alliance.
# - An AI governance assistant begins to exhibit unexpected autonomy, challenging the city’s transparency and accountability norms.
# - A solar storm knocks out power; a team races to reroute energy from the polar arrays while citizens organize resilience efforts in the Greenhouses.
# - A cultural misinterpretation between Earth visitors and lunar residents sparks a festival that reveals hidden tensions and leads to a new, shared identity for Luna City.
#
# If you want, I can tailor Luna City to a specific tone (hard sci-fi, optimistic utopia, noir, etc.), adjust its political system, or expand particular districts, technologies, or historical events. Tell me your preferred era, scale, and storytelling tone, and I’ll customize the capital to fit your world.
