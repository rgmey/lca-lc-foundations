# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.
agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61018278497431.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='966ae941-785f-4343-b9f8-5af1adda876b'),
#  AIMessage(content='', additional_kwargs={'reasoning_content': "**Calculating square root**\n\nI need to find the square root of 467. The tools provided include a square root function, which I'll use to get an accurate answer. I can estimate manually first: since 21^2 is 441 and 22^2 is 484, the square root is between those two values. I'll also use the Newton-Raphson method for precision, starting at around 21.6. I’ll refine my estimate and do some calculations to reach a six-decimal precision. Let's find that square root!**Computing long division**\n\nI’m working on the long division for 467 divided by 21.6. To make it easier, I’ll multiply both the numerator and denominator by 10 to get 4670 and 216. I calculate that 216 multiplied by 21 gives 4536, leaving a remainder of 134. Bringing down a zero, I get 1340 divided by 216, which yields about 6, and that leads to another remainder of 44. I keep going until I find that 467 divided by 21.6 is approximately 21.6203.**Refining the calculation**\n\nEarlier, I thought the square root was around 21.629, so I need to verify that. When I calculate 21.6 multiplied by 21.6203, it comes out slightly over 467. To find the precise number, I break it down into parts: 21.6 times 21 plus the product of 21.6 and 0.6203. After recalculating, I find that the division we did before gives us 21.6203, and confirming that 467 divided by 21.6 is, in fact, roughly 21.6204. Let's refine that further.**Systematic long division**\n\nI've gone through a long division process for 4670 by 216, with each step showing remainders that suggest a repeating pattern. I started by determining how many times 216 fits into 4670. After subtracting, I brought down numbers step by step: 1340, then 440, and finally 80, watching the remainders as they unfold. The consistent results point to a repeating cycle of digits. I’ll need to look at the final calculation again to confirm the pattern as it continues.**Calculating square root of 467**\n\nI’m really refining my calculations for the square root of 467! I’ve identified a repeating pattern in the decimal approximation, which is around 21.6203, but I'm getting closer to a more precise value. I think the square root is approximately 21.610. I’m planning to use the square root function directly to get this number more accurately. After performing these calculations, I’ll show the result with a clear presentation, mentioning that it’s an irrational number. Let’s call the function to finalize this!", 'reasoning_details': [{'summary': "**Calculating square root**\n\nI need to find the square root of 467. The tools provided include a square root function, which I'll use to get an accurate answer. I can estimate manually first: since 21^2 is 441 and 22^2 is 484, the square root is between those two values. I'll also use the Newton-Raphson method for precision, starting at around 21.6. I’ll refine my estimate and do some calculations to reach a six-decimal precision. Let's find that square root!**Computing long division**\n\nI’m working on the long division for 467 divided by 21.6. To make it easier, I’ll multiply both the numerator and denominator by 10 to get 4670 and 216. I calculate that 216 multiplied by 21 gives 4536, leaving a remainder of 134. Bringing down a zero, I get 1340 divided by 216, which yields about 6, and that leads to another remainder of 44. I keep going until I find that 467 divided by 21.6 is approximately 21.6203.**Refining the calculation**\n\nEarlier, I thought the square root was around 21.629, so I need to verify that. When I calculate 21.6 multiplied by 21.6203, it comes out slightly over 467. To find the precise number, I break it down into parts: 21.6 times 21 plus the product of 21.6 and 0.6203. After recalculating, I find that the division we did before gives us 21.6203, and confirming that 467 divided by 21.6 is, in fact, roughly 21.6204. Let's refine that further.**Systematic long division**\n\nI've gone through a long division process for 4 ...
#  ToolMessage(content='21.61018278497431', name='square_root', id='0a1fa1d6-2b3f-4f50-8734-e426859e4a8e', tool_call_id='call_Tit54eMZbd8ySjKgFhULWjda'),
#  AIMessage(content='The square root of 467 is approximately 21.61018278497431.', additional_kwargs={'reasoning_content': '**Responding with square root**\n\nI got the result of the square root: 21.61018278497431. To keep it concise, I\'ll say: "The square root of 467 is approximately 21.61018278497431." I can also mention that it’s an irrational number, possibly add a note like "since 21.6101^2 is about 467." However, I\'ll focus on delivering a clear, one-line response that states the answer effectively without overwhelming the user. Let\'s keep it straightforward!', 'reasoning_details': [{'summary': '**Responding with square root**\n\nI got the result of the square root: 21.61018278497431. To keep it concise, I\'ll say: "The square root of 467 is approximately 21.61018278497431." I can also mention that it’s an irrational number, possibly add a note like "since 21.6101^2 is about 467." However, I\'ll focus on delivering a clear, one-line response that states the answer effectively without overwhelming the user. Let\'s keep it straightforward!', 'type': 'reasoning.summary', 'format': 'openai-responses-v1', 'index': 0}, {'data': 'gAAAAABqix5Pr_sgLYuZj127FRaiIYG9GXaWNx8qtsSbYvtXRaeA7E4yyxNYSYqCetyYZYhanV8jK9WEi5HB3I01LgI95pWqqw0pdVAfCb5H2HrdU56GbwMTd9OfLMjBGk-pynJlTmmOnn_8NaH2M7-ffe7gDdNEeldMq9Uvuk27CLZMPIWPTKVWZh3sfZN_2VW8_5bIpqTx8_UCZiEl7mobpkD5Z_bJlU_LpU0a_EQY026JNAQdFF0fDiamfnFX6WMXwptXDPdAICq5K3Fhvs4jFuBZWsd2fT3rW2ebS71MmVp8bKlHk_ddIRy0HCKDt4rsDWQVQwSda9gZc3lkp0k-jRRoWcIRfTRj-YLkyFHgEr-yRP4KKCBT3LnTNBm-AvGd-UTgxq5c2XZMNGOJmm57YQ6bGaFMGtHKDZm4C9rxR-KAl1y81Yd3ucywlZf6xEmWXiEhT4zOS7edWO8ob41CAoo7synUoqE1HNImVLL4hfk97mqnAAyW1VAMwlzTsqmacHWX0veFSwOZ_n2caeSNTYSFw8H0auY09IcLhkJHVxGj3ts03YPLSacU1-8nE0GCFMYgMjo9w1thMYxERVv_RdoHgVEUUXAAweVfV8zW2RPO1KlmoMgIjqj8gp_Nl7N-Jo8mZp5LlIELmNhNfOleiGxmj5R9Qm8m09vvda0zKRAj9ThTZ6dIBHflIXpRzChdfd78sghAlUQEpMDgc4_kZ5uQEpnM7QqjxPKNmrQ48d4wtl2Kdp--PnAtBhciy25nBNfvY0PW59xAvf0GabRHLarDUuLBuIOWard7biCrCxOhhvD1tIcvwHI71qgBzXX4tsU-pXh5iIE5ZSmyFml-1_XeH3tnUHZ2iOfpfou8Vn8pmAMiIbRda31IdsKh3wbPnVj5_zVDu5DEHGzGFqvDT8S_X---ErjfGKIqQk1B6oBCm5QqCaIOuSQyfBAWLGNGYGAQ9FzWlkVuqJSjgYjSs15iyO1vHTy6R80kqxU_n9rm3BeUGuZ-OuS7mZoimNrld4pKIViH4J