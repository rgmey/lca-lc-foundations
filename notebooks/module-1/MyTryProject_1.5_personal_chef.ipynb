# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.
# system_prompt = """You are a cooking expert helping with recipe lookup based on available ingredients. 
# A list of ingredients will be given to you and you will find the recipes on the internet that 
# use them and present the ones that are possible to cook with the available ingredients."""
recipe_agent = create_agent(
    model=model,
    # system_prompt=system_prompt,
    tools=[web_search]
)

question = HumanMessage(content="""Tell me a few recipes I can cook some food considering available ingredients are as below:Tomatoes, Potatoes, Meat, Eggs""")

response = recipe_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Nice! Here are a few simple ideas using Tomatoes, Potatoes, Meat, and Eggs. I kept them doable in a single pan or sheet, with quick steps.
#
# 1) Tomato-Egg Shakshuka (with optional meat)
# - What you’ll need (roughly): Tomatoes (4 medium or 2 cups chopped), Eggs (4), Meat (optional, 300–400 g ground beef or chopped meat)
# - Steps:
#   - If using meat, brown it in a wide skillet. Remove excess fat if needed.
#   - Add chopped tomatoes and simmer until they form a thick sauce. Season with salt and pepper.
#   - Make 4 wells in the sauce and crack an egg into each. Cover and cook until eggs are set to your liking (soft or fully cooked).
#   - Serve with pan-fried potato slices on the side for a hearty combo.
#
# 2) Potato-Hash Skillet with Meat, Tomatoes, and Eggs
# - What you’ll need: Potatoes (2–3 large, diced), Meat (200–300 g, ground or chopped), Tomatoes (2, chopped), Eggs (2–4)
# - Steps:
#   - Dice potatoes and sauté in oil until they start to brown and soften.
#   - Add the meat and cook until browned.
#   - Stir in tomatoes and cook a few minutes to break them down.
#   - Make small wells and crack in eggs. Cook until eggs are set to your liking (covered helps).
#   - Optional: finish with a pinch of salt, pepper, and any herbs you have.
#
# 3) Potato Omelette (Spanish-style) with Tomato
# - What you’ll need: Potatoes (2–3 medium, thinly sliced), Eggs (4), Tomatoes (2, chopped or sliced)
# - Steps:
#   - Fry potatoes in a bit of oil until tender and lightly golden. Remove excess oil if needed.
#   - Beat the eggs and pour over the potatoes in the pan; cook gently until the eggs set into a firm omelette.
#   - Slice or serve with a simple tomato topping or side: just chopped tomatoes with a pinch of salt.
#   - Slice and serve as a hearty breakfast, lunch, or light dinner.
#
# 4) Beef/Tomato Potatoes Bake (one-pan)
# - What you’ll need: Meat (400–500 g, sliced or crumbled), Potatoes (3–4 medium, thinly sliced), Tomatoes (3–4, sliced or crushed)
# - Steps:
#   - Preheat oven to about 180°C (350°F).
#   - In a baking dish, layer potatoes, meat, and tomatoes. Season with salt and pepper.
#   - Cover and bake until potatoes are tender and meat is cooked through (about 35–45 minutes). If you like, remove cover for the last 10 minutes to brown the top.
#   - If you have eggs left, you can crack a few on top in the last 5–7 minutes for a baked “stamp” of eggs, though this is optional.
#
# Quick tips
# - Time: Most of these run about 20–40 minutes total depending on method and how you like your eggs.
# - Pantry boosts: A little oil, salt, pepper, and any herbs (like parsley, thyme, or paprika) go a long way. If you have onions or garlic, sauté them with the meat for extra flavor.
# - Servings: Each recipe can be scaled to 2–4 servings by adjusting the ingredient amounts.
#
# Would you like me to tailor these to a specific number of servings, or adapt for any dietary needs you have?

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.
# system_prompt = """You are a cooking expert helping with recipe lookup based on available ingredients. 
# A list of ingredients will be given to you and you will find the recipes on the internet that 
# use them and present the ones that are possible to cook with the available ingredients."""
recipe_agent = create_agent(
    model=model,
    # system_prompt=system_prompt,
    tools=[web_search]
)

question = HumanMessage(content="""Tell me a few recipes I can cook some food considering available ingredients are as below:Tomatoes, Potatoes, Meat, Eggs""")

response = recipe_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Great! Here are a few simple ideas using Tomatoes, Potatoes, Meat, and Eggs. All are stove-top friendly (and one can be baked if you prefer). I’ve kept ingredients minimal and added optional seasonings you might have.
#
# 1) One-pan Tomato, Potato & Meat Hash (with fried eggs)
# - Ingredients: Meat (diced), potatoes (cubed), tomatoes (chopped), eggs, oil, salt, pepper (and optional paprika or dried herbs)
# - Steps:
#   - Heat oil and brown the meat.
#   - Add potatoes; cook until they start to brown and soften.
#   - Stir in tomatoes; season with salt, pepper, and any spices you like.
#   - Cover and simmer until potatoes are tender.
#   - Make a few wells, crack in eggs, cover, and cook until eggs reach your preferred doneness.
# - Servings: 2–3
#
# 2) Tomato-Braised Meat with Potatoes (one-pot stew)
# - Ingredients: Meat, potatoes, tomatoes, oil, water or broth, salt, pepper
# - Steps:
#   - Brown the meat in oil.
#   - Add cubed potatoes and chopped tomatoes.
#   - Pour in enough water (or broth) to barely cover; season.
#   - Simmer 25–30 minutes until potatoes are tender and flavors meld.
# - Servings: 2–3
#
# 3) Tomato, Meat & Potato Skillet (Shakshuka-style with eggs)
# - Ingredients: Meat, tomatoes, potatoes (optional but tasty), eggs, oil, salt, pepper
# - Steps:
#   - Brown the meat in oil; if you like, add diced potatoes first to soften.
#   - Add chopped tomatoes and simmer into a sauce; season.
#   - Create spots in the sauce and crack in eggs. Cover and cook until eggs set to your liking.
# - Serving: Spoon over the potatoes on the side or mix them in.
#
# 4) Meat, Potato & Tomato Frittata (egg-based)
# - Ingredients: Eggs, potatoes, meat, tomatoes, oil, salt, pepper
# - Steps:
#   - Par-cook the potatoes until just tender.
#   - Sauté meat until browned; mix in with potatoes.
#   - Beat eggs with a pinch of salt and pepper; pour over meat & potatoes in a skillet.
#   - Top with chopped tomatoes; cook gently until the eggs set, or finish under a broiler for a few minutes.
# - Servings: 2–4
#
# Tips
# - If you only have a single pan, start with browning the meat in oil, then add potatoes and tomatoes to finish in one pot.
# - Season with salt and pepper, and add garlic powder, paprika, or dried herbs if you have them.
# - For a lighter option, use less oil and simmer rather than fry; add a splash of water if it looks dry.
# - If you have leftovers, these rehearse well—reheat gently and top with a fried egg for a quick meal.
#
# If you tell me how many people you’re cooking for and what type of meat you have (beef, pork, chicken, etc.), I can tailor one recipe with exact quantities and a precise time. Any dietary restrictions I should consider?
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.
# system_prompt = """You are a cooking expert helping with recipe lookup based on available ingredients. 
# A list of ingredients will be given to you and you will find the recipes on the internet that 
# use them and present the ones that are possible to cook with the available ingredients."""
recipe_agent = create_agent(
    model=model,
    # system_prompt=system_prompt,
    tools=[web_search]
)

question = HumanMessage(content="""Tell me a few recipes I can cook some food considering available ingredients are as below:Tomatoes, Potatoes, Meat, Eggs.
Write in Farsi please!""")

response = recipe_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# بله! با این مواد می‌تونید چند غذای ساده و خوشمزه درست کنید. در ادامه چند دستور کوتاه با Tomatoes (گوجه)، Potatoes (سیب‌زمینی)، Meat (گوشت)، Eggs (تخم‌مرغ) آمده است:
#
# - خورش گوشت با گوجه و سیب‌زمینی
#   - مواد لازم: گوشت، گوجه فرنگی، سیب‌زمینی، روغن، نمک، فلفل، آب
#   - طرز تهیه:
#     1) گوشت رو در یک قابلمه با روغن تفت بده تا رنگ بگیرد.
#     2) گوجه خردشده رو اضافه کرده و چند دقیقه تفت بده تا عطر گوجه بیاد.
#     3) سیب‌زمینی‌ها رو خرد کن و به قابلمه اضافه کن.
#     4) به اندازه کافی آب اضافه کن تا مواد پوشش داده بشند. نمک و فلفل بزن.
#     5) بگذار با حرارت کم بپزد تا گوشت و سیب‌زمینی نرم بشند (یعنی معمولاً ۲۰–۳۰ دقیقه). سرو کن.
#
# - املت گوجه و سیب‌زمینی
#   - مواد لازم: تخم‌مرغ، گوجه، سیب‌زمینی، روغن، نمک
#   - طرز تهیه:
#     1) سیب‌زمینی‌ها رو مکعبی خرد کن و در تابه با روغن کمی تفت بده تا نرم بشند.
#     2) گوجه خرد شده رو اضافه کن و چند دقیقه بگذار نرم بشه.
#     3) تخم‌مرغ‌ها رو با نمک بزن و روی مواد بریز. صبر کن تا از پایین برشته بشه و در صورت تمایل برگردان تا سمت دیگر هم پخته شه.
#
# - تخم‌مرغ با گوجه (سبک سریع)
#   - مواد لازم: تخم‌مرغ، گوجه، روغن، نمک
#   - طرز تهیه:
#     1) گوجه خرد شده رو توی تابه با کمی روغن تفت بده تا آبش کم بشه.
#     2) تخم‌مرغ‌ها رو روی گوجه بشکن و بگذار تا سفیده بسته شه و زرده کمی رقیق بمونه یا بنا به سلیقه کاملاً پخته شه.
#     3) نمک بزن و سرو کن. می‌تونی با نان یا روی برنج سرو کنی.
#
# - تابه گوشت با گوجه و سیب‌زمینی
#   - مواد لازم: گوشت، گوجه، سیب‌زمینی، روغن، نمک، فلفل
#   - طرز تهیه:
#     1) گوشت رو در تابه با روغن تفت بده تا تغییر رنگ بده.
#     2) سیب‌زمینی‌ها رو به قطعات کوچک خرد کن و به گوشت اضافه کن.
#     3) گوجه خرد شده رو اضافه کرده و کمی تفت بده.
#     4) نمک و فلفل بزن و با درب بگذار تا همه مواد با هم نرم و طعم‌دار بشند.
#
# اگر ترجیح می‌دی مقدار دقیق سهمیه غذایی (مثلاً برای چند نفر) رو بگم یا می‌خوای با روغن، نمک یا ادویه خاصی کار کنی، به من بگو تا دقیق‌تر دستورها رو متناسب با نیازت تنظیم کنم.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

from langchain_openrouter import ChatOpenRouter
model = ChatOpenRouter(model="openai/gpt-5-nano")   # or anthropic/claude-3.5-haiku, etc.
# system_prompt = """You are a cooking expert helping with recipe lookup based on available ingredients. 
# A list of ingredients will be given to you and you will find the recipes on the internet that 
# use them and present the ones that are possible to cook with the available ingredients."""
recipe_agent = create_agent(
    model=model,
    # system_prompt=system_prompt,
    tools=[web_search]
)

question = HumanMessage(content="""Tell me a few recipes I can cook some food considering available ingredients are as below:Tomatoes, Potatoes, Meat, Eggs.
Write in Farsi please!""")

response = recipe_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# خیلی خوب! با این مواد (گوجه، سیب زمینی، گوشت، تخم مرغ) چند دستور ساده می‌توانید درست کنید:
#
# 1) خورش گوشت با گوجه و سیب زمینی (یک قابلمه)
# - مواد (برای 2-3 نفر): گوشت تکه‌ای 400-500 گ، گوجه فرنگی 4-5 عدد یا معادل پوره گوجه، سیب زمینی 3 عدد متوسط، روغن، نمک، فلفل سیاه، زردچوبه (اختیاری)، آب کافی
# - روش ساده: گوشت را با روغن تفت بدهید تا تغییر رنگ دهد. گوجه را اضافه کنید تا آبش بیاید. نمک، فلفل و زردچوبه بزنید. سیب زمینی‌ها را به قطعات بزرگ اضافه کنید و به اندازه‌ای آب اضافه کنید که مواد پوشانده شوند. زیر شعله متوسط بگذارید 45-60 دقیقه بجوشد تا گوشت نرم شود. در صورت نیاز آب اضافه کنید. با نان یا برنج سرو کنید.
#
# 2) املت گوشت و گوجه و سیب زمینی
# - مواد: تخم مرغ 4-5 عدد، گوشت باقیمانده یا تکه‌ای 200-250 گ، سیب زمینی 1-2 عدد، گوجه فرنگی 2-3 عدد، روغن، نمک، فلفل، زردچوبه
# - روش ساده: سیب زمینی را نگینی یا قالب کوچک خرد کرده و در تابه با کمی روغن سرخ کنید تا طلایی شود. گوشت را اضافه کنید تا پخته شود. گوجه را خرد کنید و به مخلوط بیفزایید تا نرم شود. تخم مرغ‌ها را با نمک و فلفل بزنید و روی مخلوط بریزید تا منذبه بماند و ببندد. هم بزنید تا کل مواد آماده شود.
#
# 3) سیب زمینی و گوشت پخته در فر با گوجه
# - مواد: سیب زمینی نگینی یا ورقه شده 4 عدد، گوشت 300-400 گ، گوجه فرنگی 3-4 عدد، روغن، نمک، فلفل
# - روش ساده: فر را با 180°C گرم کنید. سیب زمینی‌ها را با کمی روغن و نمک در ظرف فر بچینید، گوشت را روی آن بگذارید و گوجه‌های حلقه شده را روی سطح بچینید. نمک و فلفل بپاشید. حدود 40-45 دقیقه در فر بپزید تا گوشت پخته و سیب زمینی نرم شود.
#
# 4) کوکو سیب زمینی با گوشت
# - مواد: سیب زمینی پخته رنده‌شده یا ریز، تخم مرغ 3-4 عدد، گوشت پخته یا خام خرد شده 150-200 گ، گوجه یا پوره گوجه نصف تا یک عدد، روغن، نمک، فلفل
# - روش ساده: سیب زمینی را با تخم مرغ و گوشت مخلوط کنید. گوجه را خرد یا رنده کنید و به مخلوط اضافه کنید. در تابه با روغن داغ، مایع را بریزید و هر طرف را چند دقیقه تا طلایی شود بپزید.
#
# نکته‌ها
# - با این مواد می‌توانید هر ترکیب را بسته به ذائقه‌تان روی گوجه خام یا پوره گوجه تمرکز دهید.
# - اگر پیاز یا سبزیجات دیگري دارید، به هر دستور اضافه کنید تا طعم richer شود.
# - اگر ملاقه یا قابلمه بزرگی دارید، همه مواد را یک‌جا در یک قابلمه بگذارید و با کمترین مقدار آب بپزید تا به خورش یا کوکو تبدیل شوند.
#
# دوست دارید یکی از این دستورها را با سطحی از ساده به مرحله به مرحله ببرم یا فقط یکی را با مدت پخت دقیق تر توضیح بدهم؟ همچنین آیا فر یا تابه دارید؟
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
